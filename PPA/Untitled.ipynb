# %%
import sys
sys.version
# Out:
# '3.9.20 (main, Oct  3 2024, 02:24:59) \n[Clang 14.0.6 ]'

# %%
# !pip install sdv
# Out:
# ...
# WARNING: Error parsing dependencies of pyodbc: Invalid version: '4.0.0-unsupported'
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/cli/base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/cli/base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/commands/install.py", line 483, in run
#     installed_versions[distribution.canonical_name] = distribution.version
#   File "/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/metadata/pkg_resources.py", line 192, in version
#     return parse_version(self._dist.version)
# ...

# %%
# !pip uninstall -y pyodbc
# Out:
# Found existing installation: pyodbc 4.0.0-unsupported
# Uninstalling pyodbc-4.0.0-unsupported:
#   Successfully uninstalled pyodbc-4.0.0-unsupported

# %%
# !pip install pyodbc==4.0.32
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyodbc: filename=pyodbc-4.0.32-cp39-cp39-macosx_11_0_arm64.whl size=64265 sha256=fa60568adc6ab17688fd4de1a8a31209b6a48b98d0244fb471671a783b7f9a76
#   Stored in directory: /Users/pramodkc/Library/Caches/pip/wheels/0f/25/cb/5b1aad00995de7d75402eb8cacd7c80466ba1899ea821d4db1
# Successfully built pyodbc
# ...

# %%
# !pip install sdv==1.4.0 ctgan==0.6.1
# Out:
# ...
# ERROR: Ignored the following versions that require a different python version: 0.10.0 Requires-Python >=3.6,<3.9; 0.10.0.dev0 Requires-Python >=3.6,<3.9; 0.10.1 Requires-Python >=3.6,<3.9; 0.10.1.dev0 Requires-Python >=3.6,<3.9; 0.11.0 Requires-Python >=3.6,<3.9; 0.11.0.dev0 Requires-Python >=3.6,<3.9; 0.12.0 Requires-Python >=3.6,<3.9; 0.12.0.dev0 Requires-Python >=3.6,<3.9; 0.12.0.dev1 Requires-Python >=3.6,<3.9; 0.12.1 Requires-Python >=3.6,<3.9; 0.12.1.dev0 Requires-Python >=3.6,<3.9; 0.2.2 Requires-Python >=3.6,<3.9; 0.2.2.dev1 Requires-Python >=3.5,<3.9; 0.2.2.dev2 Requires-Python >=3.6,<3.9; 0.2.2.dev3 Requires-Python >=3.6,<3.9; 0.3.0 Requires-Python >=3.6,<3.9; 0.3.0.dev0 Requires-Python >=3.5,<3.9; 0.3.0.dev1 Requires-Python >=3.6,<3.9; 0.3.1 Requires-Python >=3.6,<3.9; 0.3.1.dev0 Requires-Python >=3.6,<3.9; 0.3.1.dev1 Requires-Python >=3.6,<3.9; 0.3.1.dev2 Requires-Python >=3.6,<3.9; 0.3.2.dev0 Requires-Python >=3.6,<3.9; 0.3.3 Requires-Python >=3.5,<3.8; 0.3.4 Requires-Py
# ...

# %%
# !pip uninstall -y sdv ctgan rdt
# Out:
# Found existing installation: sdv 1.17.1
# Uninstalling sdv-1.17.1:
#   Successfully uninstalled sdv-1.17.1
# Found existing installation: ctgan 0.10.2
# Uninstalling ctgan-0.10.2:
#   Successfully uninstalled ctgan-0.10.2
# Found existing installation: rdt 1.13.0
# Uninstalling rdt-1.13.0:
#   Successfully uninstalled rdt-1.13.0

# %%
# !pip install sdv ctgan
# Out:
# ...
#   Using cached sdv-1.17.1-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached ctgan-0.10.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached rdt-1.13.0-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached sdv-1.17.1-py3-none-any.whl (152 kB)
# Using cached ctgan-0.10.2-py3-none-any.whl (23 kB)
# Using cached rdt-1.13.0-py3-none-any.whl (66 kB)
# ...

# %%
from sdv.tabular import CTGAN, TVAE
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
print("CTGAN and TVAE imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from sdv.tabular import CTGAN, TVAE
#       2 import pandas as pd
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'sdv'

# %%
# !pip show sdv
# Out:
# Name: sdv
# Version: 1.17.1
# Summary: Generate synthetic data for single table, multi table and sequential data
# Home-page:
# Author:
# Author-email: "DataCebo, Inc." <info@sdv.dev>
# License: BSL-1.1
# Location: /opt/anaconda3/lib/python3.9/site-packages
# Requires: boto3, botocore, cloudpickle, copulas, ctgan, deepecho, graphviz, numpy, pandas, platformdirs, pyyaml, rdt, sdmetrics, tqdm
# Required-by:

# %%
import sys
print("Python executable:", sys.executable)
# Out:
# Python executable: /Users/pramodkc/anaconda3/envs/Final_PPA/bin/python

# %%
conda activate Final_PPA
# Out:
# usage: conda [-h] [--no-plugins] [-V] COMMAND ...
# conda: error: argument COMMAND: invalid choice: 'activate' (choose from 'clean', 'compare', 'config', 'create', 'info', 'init', 'install', 'list', 'notices', 'package', 'remove', 'uninstall', 'rename', 'run', 'search', 'update', 'upgrade', 'build', 'convert', 'debug', 'develop', 'doctor', 'index', 'inspect', 'metapackage', 'render', 'skeleton', 'verify', 'content-trust', 'server', 'pack', 'repo', 'env', 'token')
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install sdv

# %%
from sdv.tabular import CTGAN, TVAE
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sdv.tabular import CTGAN, TVAE
#
# ModuleNotFoundError: No module named 'sdv'

# %%
from ctgan import load_demo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from ctgan import load_demo
#
# ModuleNotFoundError: No module named 'ctgan'

# %%
# !list
# Out:
# zsh:1: command not found: list

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- --------------------
# absl-py                            2.1.0
# aext_assistant                     0.4.0
# aext_assistant_server              0.4.0
# aext_core                          0.4.0
# aext_core_server                   0.4.0
# aext_shared                        0.4.0
# aiohttp                            3.8.4
# aiosignal                          1.3.1
# alabaster                          0.7.12
# alembic                            1.10.2
# amqp                               5.1.1
# anaconda-client                    1.9.0
# anaconda-cloud-auth                0.5.0
# anaconda-navigator                 2.3.2
# anaconda-project                   0.10.1
# annotated-types                    0.6.0
# anyio                              3.6.2
# apispec                            3.3.2
# appdirs                            1.4.4
# applaunchservices                  0.2.1
# ...
